# %% [markdown]
# # 공공데이터 API를 이용한 부동산 거래 정보

# %%
import numpy as np
import pandas as pd

yeon=pd.read_csv('/home/ngh/바탕화면/yeon2.csv')
dan=pd.read_csv('/home/ngh/바탕화면/dan2.csv')
apt=pd.read_csv('/home/ngh/바탕화면/apt2.csv')
office=pd.read_csv('/home/ngh/바탕화면/office.csv')

# %%
yeon
# Out:
#        거래금액     년   법정동    전용면적   월   주택유형  층
# 0     14000  2018   신흥동  41.130   1  연립다세대  1
# 1     26300  2018   신흥동  76.460   1  연립다세대  2
# 2     33700  2018   신흥동  59.860   1  연립다세대  3
# 3     35900  2018   신흥동  76.150   1  연립다세대  8
# 4     27700  2018   신흥동  41.850   1  연립다세대  2
# 5     24850  2018   신흥동  35.780   1  연립다세대  1
# 6     22000  2018   신흥동  55.800   1  연립다세대  2
# 7     11000  2018   신흥동  38.450   1  연립다세대 -1
# 8     26000  2018   신흥동  39.870   1  연립다세대  3
# 9     23900  2018   신흥동  34.860   1  연립다세대  3
# 10    38950  2018   신흥동  62.340   1  연립다세대  5
# 11    24200  2018   신흥동  74.120   1  연립다세대  5
# 12    13500  2018   태평동  32.940   1  연립다세대  4
# 13    14850  2018   태평동  41.170   1  연립다세대  3
# 14    15500  2018   태평동  58.240   1  연립다세대  3
# 15    15500  2018   태평동  27.310   1  연립다세대  3
# 16    11500  2018   태평동  41.310   1  연립다세대  2
# 17    12000  2018   태평동  40.350   1  연립다세대  2
# 18    10000  2018   태평동  39.375   1  연립다세대  1
# ...

# %%
dan
# Out:
#        거래금액     년   법정동     연면적 주택유형  층
# 0     26500  2018   신흥동  113.14   단독  2
# 1     35751  2018   신흥동   87.80   단독  2
# 2     32000  2018   신흥동  119.71   단독  2
# 3     30500  2018   신흥동  108.24   단독  2
# 4     26300  2018   신흥동   94.86   단독  2
# 5     29000  2018   신흥동  118.26   단독  2
# 6     29500  2018   신흥동   83.24   단독  2
# 7     26500  2018   신흥동  110.64   단독  2
# 8     30000  2018   신흥동  106.62  다가구  2
# 9     24500  2018   신흥동  110.60   단독  2
# 10    21500  2018   신흥동  118.59  다가구  2
# 11    36955  2018   신흥동  119.20  다가구  2
# 12    26000  2018   신흥동   97.77   단독  2
# 13    32936  2018   신흥동   37.75   단독  1
# 14    34800  2018   신흥동  136.77   단독  2
# 15    35830  2018   신흥동  121.00   단독  2
# 16    37500  2018   신흥동  183.52   단독  3
# 17    27000  2018   신흥동  108.45   단독  2
# 18    35600  2018   신흥동  112.22   단독  2
# 19    39980  2018   신흥동  129.27   단독  2
# 20    30800  2018   신흥동  104.12   단독  2
# 21    36000  2018   신흥동   91.25   단독  2
# ...

# %%
apt
# Out:
#        거래금액     년   법정동      전용면적   월 주택유형   층
# 0     34500  2018   신흥동   60.4800   1  아파트  12
# 1     43000  2018   신흥동   84.9000   1  아파트  11
# 38   8200  2018  25.92   신흥동   7  오피스텔   9
# 43   9400  2018  25.92   신흥동   8  오피스텔  14
# 53   8500  2017  25.92   신흥동   1  오피스텔   6
# 61   8500  2017  25.92   신흥동   3  오피스텔  11
# 72   8500  2017  25.92   신흥동   7  오피스텔   6
# 87   7550  2016  25.92   신흥동   4  오피스텔   7
# 90   7450  2016  25.92   신흥동   6  오피스텔  18
# 92   7700  2016  25.92   신흥동   6  오피스텔  12
# 99   7400  2016  25.92   신흥동   7  오피스텔   5
# 105  7900  2016  25.92   신흥동  10  오피스텔   9
# 107  8200  2016  25.92   신흥동  10  오피스텔  10

# %%
sns.swarmplot(x="measurement", y="value", hue="species",
              palette=["r", "c", "y"], data=office)

# %%
import seaborn as sns
sns.set(style="darkgrid")

g = sns.jointplot("전용면적", "거래금액", data=office, kind="reg",
                  xlim=(0, 100), ylim=(0, 50000), color="m")
# Out:
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set(style="darkgrid")

g = sns.jointplot("전용면적", "거래금액", data=apt, kind="reg",
                  xlim=(0, 100), ylim=(0, 100000), color="m")
# Out:
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set(style="darkgrid")

g = sns.jointplot("연면적", "거래금액", data=dan, kind="reg",
                  xlim=(0, 500), ylim=(0, 100000), color="m")
# Out:
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set(style="darkgrid")

g = sns.jointplot("전용면적", "거래금액", data=yeon, kind="reg",
                  xlim=(0, 100), ylim=(0, 50000), color="m")
# Out:
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set(style="darkgrid")

g = sns.jointplot("년", "거래금액", data=office_tae, kind="reg",
                  xlim=(2015, 2019), ylim=(0, 50000), color="m")
# Out:
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set(style="darkgrid", font=font_name)

g = sns.jointplot("층", "거래금액", data=apt, kind="reg",
                  xlim=(0, 25), ylim=(0, 100000), color="m")
# Out:
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/ngh/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
import seaborn as sns
sns.set(style="ticks", palette="pastel", font=font_name)

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="층", y="거래금액",
            data=dan)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
sns.set(style="ticks", palette="pastel", font=font_name)

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="층", y="거래금액",
            data=yeon)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
sns.set(style="ticks", palette="pastel", font=font_name)

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="층", y="거래금액",
            data=apt)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
sns.set(style="ticks", palette="pastel", font=font_name)

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="층", y="거래금액",
            data=office)

# %%
list(set(apt["법정동"]))
# Out:
# [' 신흥동', ' 태평동', ' 양지동', ' 산성동', ' 수진동', ' 단대동', ' 창곡동']

# %%
list(set(office["법정동"]))
# Out:
# ['(1-10)', ' 신흥동', ' 태평동', ' 수진동', ' 창곡동']

# %%
list(set(dan["법정동"]))
# Out:
# [' 신촌동',
#  ' 시흥동',
#  ' 신흥동',
#  ' 심곡동',
#  ' 오야동',
#  ' 태평동',
#  ' 양지동',
#  ' 금토동',
#  ' 산성동',
#  ' 수진동',
#  ' 사송동',
#  ' 복정동',
#  ' 단대동',
#  ' 고등동',
#  ' 상적동',
#  ' 창곡동']

# %%
list(set(yeon["법정동"]))
# Out:
# [' 신촌동',
#  ' 시흥동',
#  ' 신흥동',
#  ' 오야동',
#  ' 태평동',
#  ' 양지동',
#  ' 금토동',
#  ' 산성동',
#  ' 수진동',
#  ' 사송동',
#  ' 복정동',
#  ' 단대동',
#  ' 상적동']

# %%
import matplotlib
import matplotlib.pyplot as plt

# matplot 에서 한글을 표시하기 위한 설정
font_name = matplotlib.font_manager.FontProperties(
                fname="/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  # 한글 폰트 위치를 넣어주세요
            ).get_name()
matplotlib.rc('font', family=font_name)

# %%
from sklearn import tree
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
dtree = tree.DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=0)
dtree.fit(apt_train, np.array(apt["층"]))
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
name = np.array(list(set(apt["층"])))

# %%
l = list(apt["거래금액"])
apt_train = [l[i:i+1] for i in range(0, len(l), 1)]

# %%
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image

dot_data = export_graphviz(dtree, out_file=None, feature_names=['거래금액'],
                          class_names=name.astype(str), filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
l = list(apt_office["거래금액"])
aptoffice_train = [l[i:i+1] for i in range(0, len(l), 1)]

# %%
l = list(apt_office["주택유형2"])
aptoffice_train1 = [l[i:i+1] for i in range(0, len(l), 1)]

# %%
aptoffice_train2 = [aptoffice_train[i]+aptoffice_train1[i] for i in range(0, len(aptoffice_train), 1)]

# %%
dtree = tree.DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=0)
dtree.fit(aptoffice_train2, apt_office_y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
dot_data = export_graphviz(dtree, out_file=None, feature_names=['거래금액', '주택종류'],
                          class_names=name.astype(str), filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())

# %%
apt_office_y = [int(apt_office["층"][i]) for i in range(0, len(apt_office["층"]), 1)]

# %%
name = np.array(list(set(apt_office_y)))

# %% [markdown]
# # 오피스텔

# %%
l = list(office["거래금액"])
office_train = [l[i:i+1] for i in range(0, len(l), 1)]

# %%
office_y =  [int(office["층"][i]) for i in range(0, len(office["층"]), 1)]

# %%
dtree = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
dtree.fit(office_train, np.array(office_y))
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
name = np.array(list(set(apt_office_y)))

# %%
dot_data = export_graphviz(dtree, out_file=None, feature_names=['거래금액'],
                          class_names=name.astype(str), filled=True, rounded=True, special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
Image(graph.create_png())
